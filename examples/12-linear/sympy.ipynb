# %% [markdown]
# https://pythonru.com/biblioteki/sympy-v-python

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 7.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 4.6 MB/s eta 0:00:00m eta 0:00:010:01
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.11.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np

from matplotlib import pyplot as plt

from sympy.abc import x,y,w,o,u
from sympy import *

# %% [markdown]
# ---

# %%
expr = log(1+exp(-x))
expr
# Out:
# log(1 + exp(-x))

# %%
expr.diff(x).simplify()
# Out:
# -1/(exp(x) + 1)

# %%
arg = np.linspace(-10,10,100)
values = lambdify(x, expr)(arg)
dvalues = lambdify(x,expr.diff(x).simplify())(arg)

# %%
arg = np.linspace(-10,10,100)
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].plot(arg,values)
ax[0].grid()
ax[1].plot(arg,dvalues)
ax[1].grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
expr = (x+y)**2
expr
# Out:
# (x + y)**2

# %%
expr.expand()
# Out:
# x**2 + 2*x*y + y**2

# %% [markdown]
# ---

# %%
expr = sin(x)**2 + cos(x)**2 
expr
# Out:
# sin(x)**2 + cos(x)**2

# %%
expr.simplify()
# Out:
# 1

# %% [markdown]
# ---

# %%
expr = sympify('x**2 + 3*x + 2')
expr
# Out:
# x**2 + 3*x + 2

# %%
expr.subs(x,2)
# Out:
# 12

# %% [markdown]
# ---

# %%
expr=( x**2+2*x+1 )/(x+1)
expr
# Out:
# (x**2 + 2*x + 1)/(x + 1)

# %%
expr.simplify()
# Out:
# x + 1
